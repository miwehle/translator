# %% [markdown]
# # Translator Training

# %% [markdown]
# ## Prepare

# %%
# mount Google Drive (for datasets and checkpoints)
from google.colab import drive
drive.mount('/content/drive')

ROOT_DIR = "/content/nmt_lab"
CONFIG_FILE = f"{ROOT_DIR}/translator/configs/train_config.yaml"

# !mkdir -p {ROOT_DIR}
# %cd {ROOT_DIR}

# !git clone https://github.com/miwehle/translator.git

# %% [markdown]
# ## Train

# %% [markdown]
# ### Configure

# %%
# !cat {CONFIG_FILE}

# %%
#%%writefile {CONFIG_FILE}

# %% [markdown]
# ### Start Training

# %%
# %cd {ROOT_DIR}/translator
# !python scripts/train.py configs/train_config.yaml

# %% [markdown]
# ## Optional Helpers

# %% [markdown]
# Update local repository:

# %% [markdown]
# !git -C {ROOT_DIR}/translator pull
