# %% [markdown]
# # Translator Training

# %% [markdown]
# ## Prepare

# %%
# Google Drive mounten (für Datasets und Checkpoints)
from google.colab import drive
drive.mount('/content/drive')

# Variablen definieren
ROOT = "/content/nmt_lab"
CONFIG = f"{ROOT}/translator/configs/train_config.yaml"

# Python-Repo aus Git holen
# !mkdir -p {ROOT}
# %cd {ROOT}
# !git clone https://github.com/miwehle/translator.git

# %% [markdown]
# ## Train

# %% [markdown]
# ### Configure

# %%
# !cat {CONFIG}

# %%
#%%writefile {CONFIG}

# %% [markdown]
# ### Start Training

# %%
# %cd {ROOT}/translator
# !python scripts/train.py configs/train_config.yaml
