# %% [markdown]
# # COMET Scoring
#
# Schlankes Colab-Notebook fuer COMET-Evaluation eines vorhandenen Checkpoints.

# %%
from google.colab import drive
from pathlib import Path

drive.mount('/content/drive')

ROOT_DIR = Path('/content/nmt_lab')
#REPO_DIR = ROOT_DIR / 'translator'
#INFRA_DIR = ROOT_DIR / 'lab_infrastructure'

ROOT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/nmt_lab

# !test -d translator || git clone https://github.com/miwehle/translator.git
# !test -d lab_infrastructure || git clone https://github.com/miwehle/lab_infrastructure.git
# Out:
# /content/nmt_lab
# Cloning into 'translator'...
# remote: Enumerating objects: 1813, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 1813 (delta 19), reused 37 (delta 13), pack-reused 1758 (from 2)
# Receiving objects: 100% (1813/1813), 3.15 MiB | 3.01 MiB/s, done.
# Resolving deltas: 100% (1117/1117), done.
# Cloning into 'lab_infrastructure'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 152 (delta 75), reused 119 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 20.41 KiB | 20.41 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %% [markdown]
# ## Installation
#
# Diese Zelle installiert die benoetigten Pakete und startet danach die Runtime automatisch neu.
# Danach mit dem Smoke-Test weitermachen.

# %%
# %pip uninstall -y numpy
# %pip install -q --no-cache-dir numpy==1.26.4 sacremoses unbabel-comet

import os
os.kill(os.getpid(), 9)
# Out:
# Found existing installation: numpy 2.0.2
# Uninstalling numpy-2.0.2:
#   Successfully uninstalled numpy-2.0.2
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 10.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.5/55.5 kB 93.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 622.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 172.2 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 336.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 767.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.4/101.4 kB 745.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 244.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 321.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 330.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 789.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 465.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 231.4 MB/s eta 0:00:00 0:00:01
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-proto 1.38.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.9 which is incompatible.
# tobler 0.14.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.9 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cupy-cuda12x 14.0.1 requires numpy<2.6,>=2.0, but you have numpy 1.26.4 which is incompatible.
# grain 0.2.16 requires protobuf>=5.28.3, but you have protobuf 4.25.9 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# ydf 0.15.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.9 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Smoke Test
#
# Diese Zelle erst nach dem Runtime-Neustart ausfuehren.

# %%
import numpy
import comet

print('numpy', numpy.__version__)
print('comet', comet.__file__)
# Out:
# numpy 1.26.4
# comet /usr/local/lib/python3.12/dist-packages/comet/__init__.py

# %%
# %cd /content/nmt_lab/translator
# !python scripts/comet_score.py configs/comet_score_config_tedtalks.yaml
# Out:
# /content/nmt_lab/translator
# tokenizer_config.json: 100% 42.0/42.0 [00:00<00:00, 578kB/s]
# config.json: 1.38kB [00:00, 14.2MB/s]
# source.spm: 100% 797k/797k [00:00<00:00, 36.0MB/s]
# target.spm: 100% 768k/768k [00:00<00:00, 229MB/s]
# vocab.json: 1.27MB [00:00, 251MB/s]
# Generating train split: 849 examples [00:00, 88138.31 examples/s]
# 2026-04-15 19:08:41.237018: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776280121.246106   11656 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776280121.249377   11656 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776280121.257801   11656 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776280121.257818   11656 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776280121.257819   11656 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776280121.257821   11656 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Fetching 5 files:   0% 0/5 [00:00<?, ?it/s]
# hparams.yaml: 100% 567/567 [00:00<00:00, 9.63MB/s]
#
# LICENSE: 9.69kB [00:00, 64.6MB/s]
#
# .gitattributes: 1.48kB [00:00, 20.7MB/s]
# Fetching 5 files:  20% 1/5 [00:00<00:00,  5.31it/s]
# README.md: 3.40kB [00:00, 31.6MB/s]
#
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:00<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:00<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:00<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:00<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:00<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:01<?, ?B/s]
# checkpoints/model.ckpt:   0% 0.00/2.32G [00:01<?, ?B/s]
# checkpoints/model.ckpt:   0% 194k/2.32G [00:01<39:48, 973kB/s]
# checkpoints/model.ckpt:   3% 67.1M/2.32G [00:01<00:11, 198MB/s]
# checkpoints/model.ckpt:   9% 201M/2.32G [00:01<00:05, 414MB/s]
# checkpoints/model.ckpt:  12% 268M/2.32G [00:02<00:05, 383MB/s]
# checkpoints/model.ckpt:  17% 402M/2.32G [00:02<00:03, 487MB/s]
# checkpoints/model.ckpt:  28% 642M/2.32G [00:02<00:02, 727MB/s]
# checkpoints/model.ckpt:  31% 714M/2.32G [00:03<00:04, 367MB/s]
# checkpoints/model.ckpt:  33% 763M/2.32G [00:03<00:05, 279MB/s]
# checkpoints/model.ckpt:  35% 823M/2.32G [00:03<00:05, 283MB/s]
# checkpoints/model.ckpt:  37% 864M/2.32G [00:04<00:06, 216MB/s]
# checkpoints/model.ckpt:  39% 909M/2.32G [00:04<00:06, 219MB/s]
# checkpoints/model.ckpt:  41% 956M/2.32G [00:04<00:06, 223MB/s]
# checkpoints/model.ckpt:  43% 1.00G/2.32G [00:04<00:05, 224MB/s]
# checkpoints/model.ckpt:  51% 1.20G/2.32G [00:05<00:04, 275MB/s]
# checkpoints/model.ckpt:  65% 1.50G/2.32G [00:05<00:01, 519MB/s]
# checkpoints/model.ckpt:  93% 2.17G/2.32G [00:06<00:00, 793MB/s]
# checkpoints/model.ckpt: 100% 2.32G/2.32G [00:06<00:00, 351MB/s]
# Fetching 5 files: 100% 5/5 [00:06<00:00,  1.38s/it]
# Lightning automatically upgraded your loaded checkpoint from v1.8.3.post1 to v2.6.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../../root/.cache/huggingface/hub/models--Unbabel--wmt22-comet-da/snapshots/2760a223ac957f30acfb18c8aa649b01cf1d75f2/checkpoints/model.ckpt`
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 483kB/s]
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 9.65MB/s]
# tokenizer.json: 9.10MB [00:00, 18.3MB/s]
# config.json: 100% 616/616 [00:00<00:00, 13.6MB/s]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/core/saving.py:197: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# You are using a CUDA device ('NVIDIA RTX PRO 6000 Blackwell Server Edition') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Predicting DataLoader 0: 100% 107/107 [00:03<00:00, 28.21it/s]
# 0.5963837596707405
